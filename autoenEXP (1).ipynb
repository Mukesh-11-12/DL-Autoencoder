# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Autoencoder for Image Denoising using PyTorch

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
from torchsummary import summary

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Transform: Normalize and convert to tensor
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
# Load MNIST dataset
dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 21.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 608kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.65MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 12.8MB/s]

# %%
# Add noise to images
def add_noise(inputs, noise_factor=0.5):
    noisy = inputs + noise_factor * torch.randn_like(inputs)
    return torch.clamp(noisy, 0., 1.)

# %%
# Initialize model, loss function and optimizer
# Re-defining DenoisingAutoencoder to fix typo from cell SYqeZgc0MNGj
class DenoisingAutoencoder(nn.Module):
    def __init__(self):
      super(DenoisingAutoencoder, self).__init__() # Fixed 'suoer' to 'super' and added '()'
      self.encoder = nn.Sequential(
          nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),
          nn.ReLU(),
          nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1),
          nn.ReLU()
      )
      self.decoder = nn.Sequential(
          nn.ConvTranspose2d(32, 16, kernel_size=3,stride=2, output_padding=1, padding=1),
          nn.ReLU(),
          nn.ConvTranspose2d(16, 1, kernel_size=3,stride=2, output_padding=1, padding=1),
          nn.Sigmoid()
      )

    def forward(self, x):
      x = self.encoder(x)
      x = self.decoder(x)
      return x

model = DenoisingAutoencoder().to(device)
criterion = nn.MSELoss
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# Print model summary
summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 14, 14]             160
#               ReLU-2           [-1, 16, 14, 14]               0
#             Conv2d-3             [-1, 32, 7, 7]           4,640
#               ReLU-4             [-1, 32, 7, 7]               0
#    ConvTranspose2d-5           [-1, 16, 14, 14]           4,624
#               ReLU-6           [-1, 16, 14, 14]               0
#    ConvTranspose2d-7            [-1, 1, 28, 28]             145
#            Sigmoid-8            [-1, 1, 28, 28]               0
# ...
# Total params: 9,569
# Trainable params: 9,569
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.13
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.17
# ----------------------------------------------------------------

# %%
# Train the autoencoder
def train(model, loader, criterion, optimizer, epochs=5):
  model.train()
  print("Name:D.MUKESH")
  print("Register No:212224040204")
  for epoch in range(epochs):
    running_loss = 0.0
    for images, _ in loader:
      images = images.to(device)
      noisy_images = add_noise(images).to(device)

      outputs = model(noisy_images)
      loss = criterion(outputs, images)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step() # Corrected from optimizer() to optimizer.step()

      running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{epochs}], Loss:{(running_loss/len(loader)):.4f}") # Corrected f-string syntax

# %%
# Evaluate and visualize
def visualize_denoising(model, loader, num_images=10):
    model.eval()
    with torch.no_grad():
        for images, _ in loader:
            images = images.to(device)
            noisy_images = add_noise(images).to(device)
            outputs = model(noisy_images)
            break

    images = images.cpu().numpy()
    noisy_images = noisy_images.cpu().numpy()
    outputs = outputs.cpu().numpy()

    print("Name:D.MUKESH")
    print("Register Number:21224040204")
    plt.figure(figsize=(18, 6))
    for i in range(num_images):
        # Original
        ax = plt.subplot(3, num_images, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        ax.set_title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, num_images, i + 1 + num_images)
        plt.imshow(noisy_images[i].squeeze(), cmap='gray')
        ax.set_title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
        plt.imshow(outputs[i].squeeze(), cmap='gray')
        ax.set_title("Denoised")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Run training and visualization
criterion = nn.MSELoss() # Correctly instantiate the loss function
train(model, train_loader, criterion, optimizer, epochs=5)
visualize_denoising(model, test_loader)
# Out:
# Name:D.MUKESH
# Register No:212224040204
# Epoch [1/5], Loss:0.0439
# Epoch [2/5], Loss:0.0153
# Epoch [3/5], Loss:0.0147
# Epoch [4/5], Loss:0.0143
# Epoch [5/5], Loss:0.0141
# Name:D.MUKESH
# Register Number:21224040204
